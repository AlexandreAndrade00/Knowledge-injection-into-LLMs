# %%
import helpers
import seaborn as sns

# %%
helpers.plot_from_file("../../../outputs/llama3b-no_context.json")
helpers.plot_from_file("../../../outputs/llama3b-1hop-context.json")
helpers.plot_from_file("../../../outputs/llama3b-2hop-context.json")
