# %%
import helpers
import seaborn as sns

# %%
metrics: list[dict[str, float]] = helpers.read_metrics("../../../outputs/llama3b-no_context.json")

sim: list[float] = [e["semantic-similarity"] for e in metrics if len(e) != 0]
rouge: list[float] = [e["rouge-L"] for e in metrics if len(e) != 0]

sns.displot(sim, kde=True)
sns.displot(rouge, kde=True)

# %%
metrics: list[dict[str, float]] = helpers.read_metrics("../../../outputs/llama3b-1hop-context.json")

sim: list[float] = [e["semantic-similarity"] for e in metrics if len(e) != 0]
rouge: list[float] = [e["rouge-L"] for e in metrics if len(e) != 0]

sns.displot(sim, kde=True)
sns.displot(rouge, kde=True)
